# %%
import numpy as np

# %% [markdown]
# Vaalid Sudoku
#
# ---

# %%
s = np.array([
    [5, 3, 4, 6, 7, 8, 9, 1, 2],
    [6, 7, 2, 1, 9, 5, 3, 4, 8],
    [1, 9, 8, 3, 4, 2, 5, 6, 7],

    [8, 5, 9, 7, 6, 1, 4, 2, 3],
    [4, 2, 6, 8, 5, 3, 7, 9, 1],
    [7, 1, 3, 9, 2, 4, 8, 5, 6],

    [9, 6, 1, 5, 3, 7, 2, 8, 4],
    [2, 8, 7, 4, 1, 9, 6, 3, 5],
    [3, 4, 5, 2, 8, 6, 1, 7, 9]
])

# %%
b=np.sum(s,axis=1)
for i in b:
  if(i==45):
     print("for row it is Valid sudoku")
     break
  else:
    print("Not Sudoku")
# Out:
# for row it is Valid sudoku

# %%
b=np.sum(s,axis=1)
for i in b:
  if(i==45):
     print("for Columns it  is Valid sudoku")
     break
  else:
    print("Not Sudoku")
# Out:
# for Columns it  is Valid sudoku

# %%
s[0:3,0:3]
# Out:
# array([[5, 3, 4],
#        [6, 7, 2],
#        [1, 9, 8]])

# %%
s[0:3,3:6]
# Out:
# array([[6, 7, 8],
#        [1, 9, 5],
#        [3, 4, 2]])

# %%
s[0:3,6:9]
# Out:
# array([[9, 1, 2],
#        [3, 4, 8],
#        [5, 6, 7]])

# %%
s
# Out:
# array([[5, 3, 4, 6, 7, 8, 9, 1, 2],
#        [6, 7, 2, 1, 9, 5, 3, 4, 8],
#        [1, 9, 8, 3, 4, 2, 5, 6, 7],
#        [8, 5, 9, 7, 6, 1, 4, 2, 3],
#        [4, 2, 6, 8, 5, 3, 7, 9, 1],
#        [7, 1, 3, 9, 2, 4, 8, 5, 6],
#        [9, 6, 1, 5, 3, 7, 2, 8, 4],
#        [2, 8, 7, 4, 1, 9, 6, 3, 5],
#        [3, 4, 5, 2, 8, 6, 1, 7, 9]])

# %% [markdown]
# Using Python Same as top

# %%
for i in range(0,9,3):
  for j in range(0,9,3):
    n=(s[i:i+3,j:j+3])
    print(n.sum())
# Out:
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45

# %%
np.sum(n)
# Out:
# np.int64(45)

# %% [markdown]
# General Questions
#
# ---

# %%
import numpy as np
#   Age|AI|ML
data=np.array([
    [18,88,89],
    [21,91,90],
    [22,90,98],
    [22,65,65],
    [19,88,94]
])

# %%
#Get shape of matrix
data.shape
# Out:
# (5, 3)

# %%
#Find the avgerge age of student
np.mean(data[:,0])
# Out:
# np.float64(20.4)

# %%
# Extract AI marks of all students
data[:,1]
# Out:
# array([88, 91, 90, 65, 88])

# %%
#Find the ML Highest Marks
np.max(data[:,2])
# Out:
# np.int64(98)

# %%
#Get student of get marks in more than 90 in AI
data[data[:,1]>90]
# Out:
# array([[21, 91, 90]])

# %%
data
# Out:
# array([[18, 88, 89],
#        [21, 91, 90],
#        [22, 90, 98],
#        [22, 65, 65],
#        [19, 88, 94]])

# %%
#Increase AI marks of all student by 5
data[:,1] += 5
data
# Out:
# array([[18, 93, 89],
#        [21, 96, 90],
#        [22, 95, 98],
#        [22, 70, 65],
#        [19, 93, 94]])

# %%
#Find how many student younger gerther than 19
len(data[data[:,0] < 19])
# Out:
# 1

# %%
#Calculate the avg marks of each subject (col-wise-mean)
np.mean(data[:,1:],axis=0)
# Out:
# array([89.4, 87.2])

# %%
data
# Out:
# array([[18, 93, 89],
#        [21, 96, 90],
#        [22, 95, 98],
#        [22, 70, 65],
#        [19, 93, 94]])

# %%
#Get data student who score at least 80 in both suject
data[(data[:,1] >=80) & (data[:,2] >=80)]
# Out:
# array([[18, 93, 89],
#        [21, 96, 90],
#        [22, 95, 98],
#        [19, 93, 94]])

# %%
data
# Out:
# array([[18, 93, 89],
#        [21, 96, 90],
#        [22, 95, 98],
#        [22, 70, 65],
#        [19, 93, 94]])

# %%
  #Repalce of ML marks <75 with 0
data[:,2][data[:,2] < 75] = 0
data
# Out:
# array([[18, 93, 89],
#        [21, 96, 90],
#        [22, 95, 98],
#        [22, 70,  0],
#        [19, 93, 94]])
